# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
knn_gs_results = {
    'param_leaf_size': [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
                   10, 10, 10, 10, 10, 10, 30, 30, 30, 30, 30, 30, 30, 30,
                   30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 50, 50,
                   50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
                   50, 50, 50, 50, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70,
                   70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 90, 90, 90, 90,
                   90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90,
                   90, 90, 110, 110, 110, 110, 110, 110, 110, 110, 110,
                   110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110,
                   130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130,
                   130, 130, 130, 130, 130, 130, 130, 130, 130, 150, 150,
                   150, 150, 150, 150, 150, 150, 150, 150, 150, 150, 150,
                   150, 150, 150, 150, 150, 150, 150, 170, 170, 170, 170,
                   170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170,
                   170, 170, 170, 170, 170, 190, 190, 190, 190, 190, 190,
                   190, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190,
                   190, 190, 190], 
    'param_n_neighbors': [10, 10, 30, 30, 50, 50, 70, 70, 90, 90, 110, 110, 130,
                   130, 150, 150, 170, 170, 190, 190, 10, 10, 30, 30, 50,
                   50, 70, 70, 90, 90, 110, 110, 130, 130, 150, 150, 170,
                   170, 190, 190, 10, 10, 30, 30, 50, 50, 70, 70, 90, 90,
                   110, 110, 130, 130, 150, 150, 170, 170, 190, 190, 10,
                   10, 30, 30, 50, 50, 70, 70, 90, 90, 110, 110, 130, 130,
                   150, 150, 170, 170, 190, 190, 10, 10, 30, 30, 50, 50,
                   70, 70, 90, 90, 110, 110, 130, 130, 150, 150, 170, 170,
                   190, 190, 10, 10, 30, 30, 50, 50, 70, 70, 90, 90, 110,
                   110, 130, 130, 150, 150, 170, 170, 190, 190, 10, 10,
                   30, 30, 50, 50, 70, 70, 90, 90, 110, 110, 130, 130,
                   150, 150, 170, 170, 190, 190, 10, 10, 30, 30, 50, 50,
                   70, 70, 90, 90, 110, 110, 130, 130, 150, 150, 170, 170,
                   190, 190, 10, 10, 30, 30, 50, 50, 70, 70, 90, 90, 110,
                   110, 130, 130, 150, 150, 170, 170, 190, 190, 10, 10,
                   30, 30, 50, 50, 70, 70, 90, 90, 110, 110, 130, 130,
                   150, 150, 170, 170, 190, 190], 
    'mean_test_Accuracy': [0.78641171, 0.75788714, 0.79466518, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78639968, 0.75788413, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442748, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640569, 0.75788413, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77558862,
       0.79497811, 0.77640404, 0.79442748, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.7864087 , 0.75788714, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.7864087 , 0.75788714, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.7864087 , 0.75788714, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843], 
    'mean_test_Recall': [0.78641171, 0.75788714, 0.79466518, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78639968, 0.75788413, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442748, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640569, 0.75788413, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77558862,
       0.79497811, 0.77640404, 0.79442748, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.7864087 , 0.75788714, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.7864087 , 0.75788714, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.7864087 , 0.75788714, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79523086, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843,
       0.78640268, 0.75788112, 0.79466819, 0.76813552, 0.79563405,
       0.77231491, 0.79574839, 0.77425266, 0.79522183, 0.77559163,
       0.79497811, 0.77640404, 0.79442447, 0.77715025, 0.79390693,
       0.77776708, 0.79357595, 0.77823948, 0.79327205, 0.77855843], 
    'mean_test_Recall_on_deceased': [0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624,
       0.01007252, 0.02737518, 0.00490723, 0.02401834, 0.0002584 ,
       0.02298508, 0.        , 0.02195149, 0.        , 0.0206595 ,
       0.        , 0.01988464, 0.        , 0.01962624, 0.        ,
       0.01962624, 0.        , 0.01962624, 0.        , 0.01962624], 
    'params': [{'leaf_size': 10, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 10, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 10, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 30, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 30, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 50, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 50, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 70, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 70, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 90, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 90, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 110, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 110, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 130, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 130, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 150, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 150, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 170, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 170, 'n_neighbors': 190, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 10, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 10, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 30, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 30, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 50, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 50, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 70, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 70, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 90, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 90, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 110, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 110, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 130, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 130, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 150, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 150, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 170, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 170, 'weights': 'distance'},
            {'leaf_size': 190, 'n_neighbors': 190, 'weights': 'uniform'},
            {'leaf_size': 190, 'n_neighbors': 190, 'weights': 'distance'}]
}

# %%
results = pd.DataFrame(
    knn_gs_results['params']
)
results['mean_test_Accuracy'] = knn_gs_results['mean_test_Accuracy']
results['mean_test_Recall'] = knn_gs_results['mean_test_Recall']
results['mean_test_Recall_on_deceased'] = knn_gs_results['mean_test_Recall_on_deceased']
results
# Out:
#      leaf_size  n_neighbors   weights  mean_test_Accuracy  mean_test_Recall  \
# 0           10           10   uniform            0.786412          0.786412
# 1           10           10  distance            0.757887          0.757887
# 2           10           30   uniform            0.794665          0.794665
# 3           10           30  distance            0.768136          0.768136
# 4           10           50   uniform            0.795634          0.795634
# ..         ...          ...       ...                 ...               ...
# 195        190          150  distance            0.777767          0.777767
# 196        190          170   uniform            0.793576          0.793576
# 197        190          170  distance            0.778239          0.778239
# 198        190          190   uniform            0.793272          0.793272
# 199        190          190  distance            0.778558          0.778558
#
#      mean_test_Recall_on_deceased
# ...

# %%
results.groupby('leaf_size').agg('mean').reset_index()
# Out:
#    leaf_size  n_neighbors  mean_test_Accuracy  mean_test_Recall  \
# 0         10          100            0.783707          0.783707
# 1         30          100            0.783707          0.783707
# 2         50          100            0.783707          0.783707
# 3         70          100            0.783707          0.783707
# 4         90          100            0.783707          0.783707
# 5        110          100            0.783707          0.783707
# 6        130          100            0.783706          0.783706
# 7        150          100            0.783706          0.783706
# 8        170          100            0.783706          0.783706
# 9        190          100            0.783706          0.783706
#
#    mean_test_Recall_on_deceased
# 0                      0.011531
# 1                      0.011531
# 2                      0.011531
# 3                      0.011531
# 4                      0.011531
# 5                      0.011531
# ...

# %%
plt.plot(
    results.groupby('leaf_size').agg('mean').reset_index()['leaf_size'], 
    results.groupby('leaf_size').agg('mean').reset_index()['mean_test_Recall_on_deceased'], 
    '.r-'
)

# %%
results.to_csv('./KNN_GridSearchCV [Experimental].csv', index = False)
